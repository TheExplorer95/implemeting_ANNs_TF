# %% [markdown]
# <a href="https://colab.research.google.com/github/Spinkk/Implementing-ANNs-with-Tensorflow/blob/main/HW10_Janosch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import time
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# # 1. The Dataset

# %% [markdown]
# Load the dataset, create dictionaries and separate each word

# %%
def preprocess_strings(ds, sentence_wise=True):
    # make numpy string array from tfds    
    tfds_to_numpy = lambda x: next(iter(x))['text'].numpy()
    ds = tfds_to_numpy(ds).decode()                             
    
    # make list of just words
    ds_words = ds.lower().replace('\n', ' ').translate({ord("'"): None})
    exclude = string.punctuation.translate({ord("'"): None})
    table = ds_words.maketrans(exclude, ' '*len(exclude))                   
    ds_words = np.array(ds_words.translate(table).split())
    
    # creates two lookup tables, val->id and id->val
    val_to_id = {val: i for i, val in enumerate(sorted(set(ds_words)))}    
    id_to_val = {id_: val for val, id_ in val_to_id.items()}
    vocab_size = len(val_to_id)
    
    # define occurances of each token
    word_freq = [np.count_nonzero(ds_words==val) for _, val in id_to_val.items()]

    # create a list of words split into sentences
    if sentence_wise: 
        ds = ds.lower().replace('\n', ' ').translate({ord("'"): None})
        exclude = string.punctuation.translate({ord("'"): None, ord('.'): None})
        table = ds.maketrans(exclude, ' '*len(exclude))
        ds = ' '.join(ds.translate(table).split()).split('.')
        ds = [sentence.translate({ord("."): None}).split() for sentence in ds]        
        
        ds = [[val_to_id[word] for word in sentence] for sentence in ds]
        
    # use list of words
    else:
        ds = [val_to_id[word] for words in ds_words]
    
    return ds, val_to_id, id_to_val, word_freq, vocab_size

# %%
train_ds = tfds.load(name='tiny_shakespeare',
                    shuffle_files=False, 
                    split='train')

ds, val_to_id, id_to_val, word_freq, vocab_size = preprocess_strings(train_ds)

# %%
def gen_word_embeddings():    
    while True:
        np.random.shuffle(ds)      
        
        # for each sentence generate one target and make input, target pairs from leftover words within sentence
        for sentence in ds:
            if len(sentence) == 0: continue
            
            word_id = np.random.randint(0, len(sentence))
            word = sentence[word_id]
            
            context_window = sentence[word_id-2:word_id] + sentence[word_id+1:word_id+3]
            np.random.shuffle(context_window)
            
            for target in context_window:
                yield word, target
                
gen = gen_word_embeddings()
    
train_ds = tf.data.Dataset.from_generator(gen_word_embeddings,
                               output_signature=(tf.TensorSpec(shape=(), dtype=tf.int64),
                                                 tf.TensorSpec(shape=(), dtype=tf.int64)))
    
train_ds = train_ds.batch(32).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # 2.2 Model

# %%
class SkipGram(tf.keras.layers.Layer):
    def __init__(self, num_vocabulary, embedding_dim=64, num_negative_samples=100, word_frequencies=word_freq):
        super(SkipGram, self).__init__()
        self.v = num_vocabulary
        self.h = embedding_dim
        self.num_neg = num_negative_samples
        self.word_freq = word_frequencies
    
    def build(self,_):
        self.embedding_mat = self.add_weight(shape=(self.v, self.h),
                                             initializer="random_normal",
                                             trainable=True) 
        self.output_mat = self.add_weight(shape=(self.v, self.h),
                                          initializer="random_normal",
                                          trainable=True) 
        self.output_bias = self.add_weight(shape=(self.v,),
                                           initializer="random_normal",
                                           trainable=True)

    def call(self, input_id, target_id):
        # (batch,h) = from (v,h) select 'batch_num' v* by lookup
        embedding_vec = tf.nn.embedding_lookup(self.embedding_mat, input_id)
        
        # output indices
        true_classes = tf.expand_dims(target_id, axis=1) # (batch,1)
        # used for negative sampling based on word frequencies
        negative_sample_dist = tf.random.fixed_unigram_candidate_sampler(true_classes=true_classes,
                                                                         num_true=1,
                                                                         num_sampled=self.num_neg,
                                                                         unique=False,
                                                                         range_max=self.v,
                                                                         unigrams=self.word_freq)
        # compute score vector, softmax of it and loss in one function call
        loss = tf.nn.nce_loss(weights=self.output_mat,  # (v,h)
                              biases=self.output_bias,  # (v,)
                              labels=true_classes,  # (batch,1)
                              inputs=embedding_vec,  # (batch,h)
                              num_sampled=self.num_neg,
                              num_classes=self.v,
                              sampled_values = negative_sample_dist)  
        return tf.math.reduce_mean(loss)  # average over loss of each sample

    def embedding(self, input_id):
        return tf.nn.embedding_lookup(self.embedding_mat, input_id)

# %% [markdown]
# # 2.3 Training

# %%
# @tf.function
def train_step(model, input_batch, target_batch, optimizer):
    '''
    Training for one batch
    '''

    with tf.GradientTape() as tape:
        loss = model(input_batch, target_batch)  # call directly returns the loss
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

        return loss

def nearest_neighbours(model, num_vocab, selected_word_id, val_dict, k=5):
    '''
    For selected words, find out k neighbouring words and print them
    '''

    cosine_similarity = lambda x,y : np.dot(x,y) / (np.linalg.norm(x) * np.linalg.norm(y))

    # embeddings of words
    embedding_selected_word = skipgram.embedding(tf.constant(selected_word_id))
    embedding_every_word = skipgram.embedding(tf.constant(list(range(num_vocab))))

    # fit nearest neighbours using cosine similarity and embeddings of all words
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='ball_tree', metric=cosine_similarity)
    nbrs.fit(embedding_every_word)
    # find k_nearest nbrs of selected words. dim:(num_selected, k)
    id_nbrs = nbrs.kneighbors(embedding_selected_word, n_neighbors=k, return_distance=False)
    
    # print neighbours in words instead of id
    for i, sel_w_id in enumerate(selected_word_id):
        query_w = val_dict[sel_w_id]
        neigh_w = []
        for j in range(k):
            neigh_w.append(val_dict[id_nbrs[i,j]])
        print('{} {} most similar words: {}'.format(query_w, k, neigh_w))

# %%
learning_rate = 0.001

# define model
skipgram = SkipGram(num_vocabulary=vocab_size)

# define optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate)

# initialize the logger for Tensorboard visualization
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = 'logs/' + current_time + '/train'    
train_summary_writer = tf.summary.create_file_writer(train_log_dir)

# %%
epochs = 50
selected_words = [val_to_id[word] for word in ['queen', 'throne', 'wine', 'poison', 'love', 'strong', 'day', 'the']]

for epoch in range(epochs):
    print('\nEpoch: ', epoch)
    ### Training step
    train_losses = []  # each entry is averaged loss of each batch
    
    # train over all batches
    for input_batch, target_batch in train_ds.take(100):
        train_losses.append(train_step(skipgram, input_batch, target_batch, optimizer))
    
    # log train loss
    with train_summary_writer.as_default():  
        tf.summary.scalar('loss', np.mean(train_losses), step=epoch)

    ### Nearest neighbours to check embeddings
    nearest_neighbours(skipgram, vocab_size, selected_words, id_to_val)
# Out:
# Epoch:  0
# queen 5 most similar words: ['loudst', 'coldest', 'undertaen', 'glimpse', 'pursuit']
# throne 5 most similar words: ['coldest', 'scandald', 'lots', 'profit', 'wakefield']
# wine 5 most similar words: ['pugging', 'valentine', 'unvulnerable', 'lots', 'unbarbed']
# poison 5 most similar words: ['woo', 'fade', 'terrible', 'unskilfully', 'meal']
# love 5 most similar words: ['meal', 'strengthend', 'woo', 'ashore', 'lots']
# strong 5 most similar words: ['mistaking', 'unskilfully', 'morrow', 'remembrances', 'talks']
# day 5 most similar words: ['planets', 'rend', 'omit', 'lots', 'talks']
# the 5 most similar words: ['profit', 'morrow', 'mistaking', 'lots', 'unjust']
#
# Epoch:  1
# queen 5 most similar words: ['light', 'drawn', 'denials', 'endures', 'tuae']
# throne 5 most similar words: ['level', 'sunders', 'wolvish', 'continuance', 'according']
# wine 5 most similar words: ['drest', 'expedient', 'level', 'swift', 'unsaluted']
# poison 5 most similar words: ['glove', 'offering', 'eunuch', 'earth', 'perch']
# love 5 most similar words: ['player', 'tuae', 'ought', 'renown', 'flamens']
# strong 5 most similar words: ['dost', 'ought', 'drawn', 'beseem', 'glove']
# day 5 most similar words: ['perch', 'expedient', 'unsaluted', 'mine', 'continuance']
# the 5 most similar words: ['abused', 'flexible', 'flamens', 'player', 'blades']
#
# Epoch:  2
# queen 5 most similar words: ['fields', 'slaves', 'givings', 'hoarse', 'chastised']
# throne 5 most similar words: ['met', 'pernicious', 'chastised', 'unsettled', 'woollen']
# wine 5 most similar words: ['hoarse', 'givings', 'daintiness', 'amity', 'cape']
# poison 5 most similar words: ['propagation', 'met', 'tottering', 'heaviness', 'wade']
# love 5 most similar words: ['entreats', 'plot', 'food', 'impeach', 'passed']
# strong 5 most similar words: ['pernicious', 'impeach', 'recourse', 'christs', 'wade']
# day 5 most similar words: ['unsettled', 'food', 'daintiness', 'treads', 'givings']
# the 5 most similar words: ['food', 'tree', 'slaves', 'fields', 'unsettled']
#
# Epoch:  3
# queen 5 most similar words: ['ostler', 'light', 'stoccata', 'mab', 'feign']
# throne 5 most similar words: ['simple', 'musician', 'another', 'afraid', 'partake']
# wine 5 most similar words: ['musician', 'simple', 'penalty', 'light', 'meanings']
# poison 5 most similar words: ['seemers', 'alabaster', 'accompanied', 'stoccata', 'smother']
# love 5 most similar words: ['repaird', 'stoccata', 'meanings', 'ribs', 'light']
# strong 5 most similar words: ['seemers', 'becomet', 'follower', 'alabaster', 'forspent']
# day 5 most similar words: ['punish', 'ribs', 'feign', 'absolutely', 'follower']
# the 5 most similar words: ['hewing', 'uncoverd', 'covet', 'taket', 'brittle']
#
# Epoch:  4
# queen 5 most similar words: ['bewept', 'recoverd', 'almsmans', 'warmth', 'noon']
# throne 5 most similar words: ['musician', 'partake', 'sums', 'proportionable', 'sweart']
# wine 5 most similar words: ['rescue', 'musician', 'songs', 'proportionable', 'swim']
# poison 5 most similar words: ['sweart', 'bewept', 'shrug', 'oils', 'gain']
# love 5 most similar words: ['almsmans', 'bewept', 'caroused', 'measured', 'warmth']
# strong 5 most similar words: ['beseem', 'twist', 'songs', 'ribs', 'noon']
# day 5 most similar words: ['confesses', 'plagued', 'warmth', 'gain', 'bewept']
# the 5 most similar words: ['almsmans', 'bewept', 'plagued', 'warmth', 'muffle']
#
# Epoch:  5
# queen 5 most similar words: ['recoverd', 'oerborne', 'noon', 'conserves', 'forgetst']
# throne 5 most similar words: ['simple', 'sped', 'oaths', 'prison', 'congregations']
# wine 5 most similar words: ['tarquin', 'simple', 'villain', 'learn', 'mates']
# poison 5 most similar words: ['seemers', 'griefs', 'mates', 'express', 'terrible']
# love 5 most similar words: ['meanings', 'vented', 'claps', 'ribs', 'swarming']
# strong 5 most similar words: ['marigold', 'oaths', 'seemers', 'griefs', 'strive']
# day 5 most similar words: ['plagued', 'nameless', 'gawded', 'squarest', 'daintiness']
# the 5 most similar words: ['recoverd', 'forgetst', 'meanings', 'ribs', 'mates']
#
# Epoch:  6
# queen 5 most similar words: ['grown', 'slaves', 'rides', 'widower', 'doublets']
# throne 5 most similar words: ['habitation', 'nobody', 'callat', 'uncleanness', 'haled']
# wine 5 most similar words: ['haled', 'uncleanness', 'intercepts', 'parish', 'wilful']
# poison 5 most similar words: ['rides', 'christend', 'slaves', 'chronicle', 'invocation']
# love 5 most similar words: ['grown', 'slaves', 'doublets', 'spilling', 'pash']
# strong 5 most similar words: ['trow', 'dignifies', 'knockd', 'alabaster', 'widower']
# day 5 most similar words: ['grown', 'rides', 'confesses', 'trusts', 'pash']
# the 5 most similar words: ['hangmen', 'racks', 'handling', 'petitionary', 'villany']
#
# Epoch:  7
# queen 5 most similar words: ['hangmen', 'belie', 'wallow', 'punish', 'duns']
# throne 5 most similar words: ['punish', 'gain', 'huntsman', 'lists', 'sobriety']
# wine 5 most similar words: ['wallow', 'strength', 'punish', 'delphos', 'meanings']
# poison 5 most similar words: ['gain', 'wreaths', 'rarest', 'wept', 'duns']
# love 5 most similar words: ['hangmen', 'belie', 'wallow', 'meanings', 'punish']
# strong 5 most similar words: ['boat', 'oaths', 'thomas', 'wept', 'witless']
# day 5 most similar words: ['punish', 'hangmen', 'wallow', 'duns', 'gain']
# the 5 most similar words: ['spawn', 'demigod', 'maintain', 'achieving', 'misery']
#
# Epoch:  8
# queen 5 most similar words: ['belie', 'punish', 'duns', 'rarest', 'gain']
# throne 5 most similar words: ['apothecary', 'punish', 'gain', 'huntsman', 'lists']
# wine 5 most similar words: ['apothecary', 'tarquin', 'strength', 'punish', 'delphos']
# poison 5 most similar words: ['gain', 'rarest', 'duns', 'wreaths', 'swarming']
# love 5 most similar words: ['belie', 'punish', 'meanings', 'duns', 'swarming']
# strong 5 most similar words: ['oaths', 'thomas', 'strength', 'rarest', 'yours']
# day 5 most similar words: ['punish', 'duns', 'gawded', 'gain', 'belie']
# the 5 most similar words: ['hewing', 'wallow', 'schoold', 'lullaby', 'opportunity']
#
# Epoch:  9
# queen 5 most similar words: ['nomination', 'hangmen', 'wallow', 'painting', 'rarest']
# throne 5 most similar words: ['behind', 'frost', 'huntsman', 'disdaind', 'hangmen']
# wine 5 most similar words: ['wallow', 'delphos', 'meanings', 'usuries', 'stalls']
# poison 5 most similar words: ['nomination', 'saved', 'rarest', 'workmanly', 'wallow']
# love 5 most similar words: ['nomination', 'hangmen', 'wallow', 'meanings', 'blubbering']
# strong 5 most similar words: ['wounded', 'thomas', 'wept', 'painting', 'disdaind']
# day 5 most similar words: ['nomination', 'hangmen', 'wallow', 'stalls', 'saved']
# the 5 most similar words: ['direct', 'former', 'proceeding', 'chronicle', 'demise']
#
# Epoch:  10
# queen 5 most similar words: ['inn', 'livery', 'virginal', 'sweetst', 'beam']
# throne 5 most similar words: ['plaining', 'demigod', 'hangmen', 'maintain', 'recoverd']
# wine 5 most similar words: ['cold', 'flout', 'achieving', 'maintain', 'spawn']
# poison 5 most similar words: ['saved', 'vouches', 'maintain', 'plaining', 'rarest']
# love 5 most similar words: ['achieving', 'hangmen', 'spawn', 'vouches', 'demigod']
# strong 5 most similar words: ['maintain', 'painting', 'rarest', 'cold', 'hangmen']
# day 5 most similar words: ['hangmen', 'achieving', 'vouches', 'plaining', 'spawn']
# the 5 most similar words: ['rumourer', 'skyey', 'refuse', 'services', 'adoreth']
#
# Epoch:  11
# queen 5 most similar words: ['hangmen', 'recoverd', 'spilling', 'painting', 'rarest']
# throne 5 most similar words: ['lists', 'hangmen', 'recoverd', 'thinly', 'wakes']
# wine 5 most similar words: ['inn', 'achieving', 'beam', 'ruthful', 'plantagenets']
# poison 5 most similar words: ['apprehends', 'spilling', 'thinly', 'recoverd', 'hangmen']
# love 5 most similar words: ['hangmen', 'julietta', 'spilling', 'recoverd', 'ribs']
# strong 5 most similar words: ['painting', 'thinly', 'scoffing', 'hangmen', 'ribs']
# day 5 most similar words: ['persuading', 'hangmen', 'beam', 'inn', 'achieving']
# the 5 most similar words: ['poisoner', 'scruples', 'undeck', 'riddling', 'street']
#
# Epoch:  12
# queen 5 most similar words: ['dwelling', 'patchd', 'bier', 'unmoand', 'tuners']
# throne 5 most similar words: ['foolishly', 'thraldom', 'workmanly', 'unmoand', 'magnificence']
# wine 5 most similar words: ['patchd', 'tuners', 'unsatiate', 'unmoand', 'exposed']
# poison 5 most similar words: ['dwelling', 'workmanly', 'unmoand', 'patchd', 'bier']
# love 5 most similar words: ['patchd', 'bier', 'dwelling', 'unmoand', 'unsatiate']
# strong 5 most similar words: ['patchd', 'dwelling', 'clean', 'bier', 'overlook']
# day 5 most similar words: ['whistling', 'dwelling', 'delectable', 'bier', 'patchd']
# the 5 most similar words: ['dwelling', 'patchd', 'bier', 'overlook', 'unmoand']
#
# Epoch:  13
# queen 5 most similar words: ['denying', 'property', 'sugar', 'terrors', 'vault']
# throne 5 most similar words: ['covenant', 'foolishly', 'claps', 'workmanly', 'borough']
# wine 5 most similar words: ['denying', 'unmoand', 'sugar', 'property', 'perch']
# poison 5 most similar words: ['property', 'sugar', 'seemers', 'scroll', 'workmanly']
# love 5 most similar words: ['denying', 'property', 'terrors', 'sugar', 'unmoand']
# strong 5 most similar words: ['seemers', 'denying', 'sugar', 'terrors', 'scoffing']
# day 5 most similar words: ['denying', 'perch', 'vault', 'property', 'unmoand']
# the 5 most similar words: ['denying', 'property', 'sugar', 'terrors', 'vault']
#
# Epoch:  14
# queen 5 most similar words: ['distemperature', 'butt', 'ifs', 'tying', 'cuckolds']
# throne 5 most similar words: ['impartial', 'flung', 'jesus', 'incorporate', 'advantage']
# wine 5 most similar words: ['tying', 'butt', 'stays', 'nails', 'ifs']
# poison 5 most similar words: ['conquerors', 'tying', 'mount', 'secret', 'ifs']
# love 5 most similar words: ['conquerors', 'cuckolds', 'distemperature', 'ifs', 'rod']
# strong 5 most similar words: ['jesus', 'butt', 'follower', 'nails', 'hottest']
# day 5 most similar words: ['ifs', 'distemperature', 'rod', 'conquerors', 'impartial']
# the 5 most similar words: ['ifs', 'cuckolds', 'distemperature', 'conquerors', 'butt']
#
# Epoch:  15
# queen 5 most similar words: ['distemperature', 'butt', 'tying', 'majestical', 'conquerors']
# throne 5 most similar words: ['impartial', 'flung', 'jesus', 'majestical', 'incorporate']
# wine 5 most similar words: ['tying', 'butt', 'stays', 'nails', 'wherewithal']
# poison 5 most similar words: ['conquerors', 'tying', 'mount', 'secret', 'distemperature']
# love 5 most similar words: ['conquerors', 'majestical', 'distemperature', 'rod', 'incorporate']
# strong 5 most similar words: ['jesus', 'butt', 'follower', 'nails', 'hottest']
# day 5 most similar words: ['majestical', 'distemperature', 'rod', 'conquerors', 'impartial']
# the 5 most similar words: ['distemperature', 'majestical', 'conquerors', 'butt', 'rod']
#
# Epoch:  16
# queen 5 most similar words: ['dubbd', 'tullus', 'hangmen', 'trusts', 'jule']
# throne 5 most similar words: ['crete', 'treaty', 'excepting', 'refrain', 'dubbd']
# wine 5 most similar words: ['dubbd', 'crete', 'jule', 'trusts', 'tullus']
# poison 5 most similar words: ['dubbd', 'tullus', 'manes', 'crete', 'rod']
# love 5 most similar words: ['dubbd', 'tullus', 'rod', 'crete', 'poland']
# strong 5 most similar words: ['dubbd', 'poland', 'racks', 'intitle', 'hangmen']
# day 5 most similar words: ['dubbd', 'tullus', 'rod', 'treaty', 'trusts']
# the 5 most similar words: ['dubbd', 'tullus', 'rod', 'trusts', 'hangmen']
#
# Epoch:  17
# queen 5 most similar words: ['torture', 'hoarded', 'quoifs', 'achieving', 'opposed']
# throne 5 most similar words: ['weaker', 'quenchless', 'quoifs', 'professed', 'delectable']
# wine 5 most similar words: ['demise', 'thresher', 'torture', 'opposed', 'achieving']
# poison 5 most similar words: ['hoarded', 'opposed', 'torture', 'thresher', 'workmanly']
# love 5 most similar words: ['hoarded', 'torture', 'achieving', 'quoifs', 'travelling']
# strong 5 most similar words: ['torture', 'thresher', 'spite', 'demise', 'puts']
# day 5 most similar words: ['hoarded', 'torture', 'travelling', 'quoifs', 'achieving']
# the 5 most similar words: ['torture', 'hoarded', 'travelling', 'opposed', 'quoifs']
#
# Epoch:  18
# queen 5 most similar words: ['torture', 'hoarded', 'quoifs', 'achieving', 'opposed']
# throne 5 most similar words: ['weaker', 'quenchless', 'quoifs', 'professed', 'delectable']
# wine 5 most similar words: ['demise', 'thresher', 'torture', 'opposed', 'achieving']
# poison 5 most similar words: ['hoarded', 'opposed', 'torture', 'thresher', 'workmanly']
# love 5 most similar words: ['hoarded', 'torture', 'achieving', 'quoifs', 'travelling']
# strong 5 most similar words: ['torture', 'thresher', 'spite', 'demise', 'parentage']
# day 5 most similar words: ['hoarded', 'torture', 'travelling', 'quoifs', 'achieving']
# the 5 most similar words: ['torture', 'hoarded', 'travelling', 'opposed', 'quoifs']
#
# Epoch:  19
# queen 5 most similar words: ['recover', 'ice', 'cured', 'aiding', 'adoreth']
# throne 5 most similar words: ['aiding', 'ice', 'nobility', 'remnant', 'simply']
# wine 5 most similar words: ['recover', 'adoreth', 'unsaluted', 'ice', 'cured']
# poison 5 most similar words: ['ice', 'recover', 'shady', 'begot', 'eld']
# love 5 most similar words: ['recover', 'ice', 'cured', 'chid', 'aiding']
# strong 5 most similar words: ['simply', 'ice', 'unable', 'hearty', 'recover']
# day 5 most similar words: ['recover', 'ice', 'cured', 'eld', 'chid']
# the 5 most similar words: ['recover', 'ice', 'cured', 'chid', 'unable']
#
# Epoch:  20
# queen 5 most similar words: ['seasons', 'undiscernible', 'chiders', 'quoifs', 'unvenerable']
# throne 5 most similar words: ['unvenerable', 'undiscernible', 'cats', 'seasons', 'chiders']
# wine 5 most similar words: ['undiscernible', 'chiders', 'seasons', 'navel', 'viewing']
# poison 5 most similar words: ['undiscernible', 'seasons', 'chiders', 'added', 'intercepted']
# love 5 most similar words: ['seasons', 'chiders', 'undiscernible', 'quoifs', 'navel']
# strong 5 most similar words: ['seasons', 'reprieves', 'encamp', 'greediness', 'groats']
# day 5 most similar words: ['chiders', 'seasons', 'undiscernible', 'unvenerable', 'quoifs']
# the 5 most similar words: ['seasons', 'chiders', 'undiscernible', 'quoifs', 'unvenerable']
#
# Epoch:  21
# queen 5 most similar words: ['quoifs', 'hyperbolical', 'unvenerable', 'deputation', 'unmeet']
# throne 5 most similar words: ['unvenerable', 'unmeet', 'sustain', 'deputation', 'breathest']
# wine 5 most similar words: ['hyperbolical', 'grating', 'quoifs', 'deputation', 'doubleness']
# poison 5 most similar words: ['breathest', 'quoifs', 'unvenerable', 'quaked', 'unmeet']
# love 5 most similar words: ['hyperbolical', 'deputation', 'quoifs', 'unvenerable', 'grating']
# strong 5 most similar words: ['unmeet', 'distaffs', 'deceiveable', 'doubleness', 'foreign']
# day 5 most similar words: ['unvenerable', 'hyperbolical', 'unmeet', 'grating', 'quoifs']
# the 5 most similar words: ['hyperbolical', 'quoifs', 'unvenerable', 'grating', 'deputation']
#
# Epoch:  22
# queen 5 most similar words: ['seasons', 'quoifs', 'unvenerable', 'added', 'navel']
# throne 5 most similar words: ['unvenerable', 'cats', 'seasons', 'breathest', 'quoifs']
# wine 5 most similar words: ['seasons', 'navel', 'quoifs', 'intercepted', 'exposed']
# poison 5 most similar words: ['seasons', 'added', 'intercepted', 'breathest', 'quoifs']
# love 5 most similar words: ['seasons', 'quoifs', 'navel', 'unvenerable', 'added']
# strong 5 most similar words: ['seasons', 'encamp', 'groats', 'cats', 'galld']
# day 5 most similar words: ['seasons', 'unvenerable', 'quoifs', 'added', 'navel']
# the 5 most similar words: ['seasons', 'quoifs', 'unvenerable', 'added', 'navel']
#
# Epoch:  23
# queen 5 most similar words: ['seasons', 'inferring', 'passengers', 'consuming', 'violate']
# throne 5 most similar words: ['unvenerable', 'seasons', 'breathest', 'instinct', 'exposed']
# wine 5 most similar words: ['seasons', 'adoreth', 'navel', 'veronas', 'intercepted']
# poison 5 most similar words: ['seasons', 'breathest', 'unvenerable', 'worships', 'herdsmen']
# love 5 most similar words: ['seasons', 'navel', 'added', 'eve', 'worships']
# strong 5 most similar words: ['seasons', 'groats', 'cats', 'worships', 'galld']
# day 5 most similar words: ['unfeeling', 'poland', 'cambrics', 'skyey', 'meekness']
# the 5 most similar words: ['passengers', 'inferring', 'consuming', 'upper', 'violate']
#
# Epoch:  24
# queen 5 most similar words: ['seasons', 'cakes', 'consuming', 'hells', 'refuse']
# throne 5 most similar words: ['seasons', 'breathest', 'instinct', 'exposed', 'galld']
# wine 5 most similar words: ['seasons', 'adoreth', 'navel', 'intercepted', 'comb']
# poison 5 most similar words: ['seasons', 'breathest', 'worships', 'herdsmen', 'exposed']
# love 5 most similar words: ['seasons', 'navel', 'eve', 'worships', 'intercepted']
# strong 5 most similar words: ['seasons', 'comb', 'edict', 'mount', 'navel']
# day 5 most similar words: ['unfeeling', 'poland', 'seasons', 'meekness', 'hyperbolical']
# the 5 most similar words: ['seasons', 'poland', 'unfeeling', 'meekness', 'hyperbolical']
#
# Epoch:  25
# queen 5 most similar words: ['seasons', 'oppress', 'handling', 'confesses', 'jested']
# throne 5 most similar words: ['cats', 'seasons', 'breathest', 'determine', 'galld']
# wine 5 most similar words: ['seasons', 'adoreth', 'tuners', 'grating', 'deputation']
# poison 5 most similar words: ['seasons', 'intercepted', 'breathest', 'worships', 'herdsmen']
# love 5 most similar words: ['seasons', 'unfeeling', 'poland', 'hyperbolical', 'dangerously']
# strong 5 most similar words: ['seasons', 'comb', 'edict', 'doubleness', 'foreign']
# day 5 most similar words: ['unfeeling', 'poland', 'seasons', 'meekness', 'hyperbolical']
# the 5 most similar words: ['seasons', 'poland', 'unfeeling', 'meekness', 'hyperbolical']
#
# Epoch:  26
# queen 5 most similar words: ['hereby', 'orange', 'parchd', 'distinguishd', 'ransackd']
# throne 5 most similar words: ['behests', 'wreak', 'mads', 'idles', 'acted']
# wine 5 most similar words: ['unarmd', 'importuned', 'named', 'idles', 'behests']
# poison 5 most similar words: ['importuned', 'idles', 'enshield', 'drench', 'named']
# love 5 most similar words: ['bar', 'pout', 'merited', 'antipodes', 'wheresoeer']
# strong 5 most similar words: ['importuned', 'cable', 'named', 'descended', 'idles']
# day 5 most similar words: ['distinguishd', 'orange', 'murders', 'hereby', 'ransackd']
# the 5 most similar words: ['distinguishd', 'hereby', 'orange', 'parchd', 'murders']
#
# Epoch:  27
# queen 5 most similar words: ['sinks', 'consuming', 'sweetmeats', 'cynthias', 'veronas']
# throne 5 most similar words: ['cynthias', 'pose', 'ominous', 'sinks', 'aunts']
# wine 5 most similar words: ['sinks', 'cynthias', 'veronas', 'jollity', 'sweetmeats']
# poison 5 most similar words: ['sinks', 'veronas', 'partlet', 'blessd', 'sweetmeats']
# love 5 most similar words: ['sinks', 'sweetmeats', 'cynthias', 'consuming', 'pose']
# strong 5 most similar words: ['cynthias', 'sinks', 'partlet', 'jollity', 'descended']
# day 5 most similar words: ['sinks', 'sweetmeats', 'pose', 'cynthias', 'veronas']
# the 5 most similar words: ['waken', 'consuming', 'mistresses', 'growth', 'r']
#
# Epoch:  28
# queen 5 most similar words: ['border', 'wheresoeer', 'suburbs', 'inkling', 'soaking']
# throne 5 most similar words: ['miracle', 'chastity', 'riddle', 'ministerd', 'border']
# wine 5 most similar words: ['suburbs', 'border', 'admirable', 'wheresoeer', 'soaking']
# poison 5 most similar words: ['wheresoeer', 'suburbs', 'safely', 'psalms', 'soaking']
# love 5 most similar words: ['border', 'wheresoeer', 'suburbs', 'soaking', 'inkling']
# strong 5 most similar words: ['wheresoeer', 'suburbs', 'border', 'admirable', 'miracle']
# day 5 most similar words: ['border', 'soaking', 'wheresoeer', 'suburbs', 'inkling']
# the 5 most similar words: ['border', 'wheresoeer', 'suburbs', 'soaking', 'inkling']
#
# Epoch:  29
# queen 5 most similar words: ['anothers', 'tying', 'carters', 'visiting', 'english']
# throne 5 most similar words: ['unshapen', 'incorporate', 'cowardice', 'poland', 'deliberate']
# wine 5 most similar words: ['poland', 'cambrics', 'fits', 'jollity', 'plucking']
# poison 5 most similar words: ['dwelling', 'manes', 'poland', 'incorporate', 'cambrics']
# love 5 most similar words: ['sinks', 'pots', 'tide', 'mount', 'veronas']
# strong 5 most similar words: ['poland', 'dwelling', 'follower', 'incorporate', 'licence']
# day 5 most similar words: ['sinks', 'pots', 'sues', 'veronas', 'mount']
# the 5 most similar words: ['waken', 'consuming', 'growth', 'r', 'hid']
#
# Epoch:  30
# queen 5 most similar words: ['border', 'lendings', 'divides', 'violate', 'sixth']
# throne 5 most similar words: ['scowl', 'miracle', 'riddle', 'ministerd', 'number']
# wine 5 most similar words: ['princox', 'merited', 'scowl', 'soaking', 'inkling']
# poison 5 most similar words: ['merited', 'princox', 'scowl', 'soaking', 'cue']
# love 5 most similar words: ['merited', 'soaking', 'princox', 'inkling', 'degrees']
# strong 5 most similar words: ['recounted', 'named', 'miracle', 'scatterd', 'princox']
# day 5 most similar words: ['named', 'fundamental', 'hairless', 'unarmd', 'appears']
# the 5 most similar words: ['border', 'divides', 'hastily', 'lendings', 'sixth']
#
# Epoch:  31
# queen 5 most similar words: ['border', 'lendings', 'divides', 'violate', 'sixth']
# throne 5 most similar words: ['scowl', 'riddle', 'tax', 'progress', 'degrees']
# wine 5 most similar words: ['merited', 'importuned', 'scowl', 'distraind', 'degrees']
# poison 5 most similar words: ['importuned', 'merited', 'safely', 'scowl', 'lines']
# love 5 most similar words: ['enfranchised', 'falcon', 'hairs', 'libels', 'pines']
# strong 5 most similar words: ['sap', 'importuned', 'quarterd', 'named', 'baldpate']
# day 5 most similar words: ['peruse', 'poland', 'arbitrement', 'mongers', 'suburbs']
# the 5 most similar words: ['border', 'divides', 'hastily', 'lendings', 'sixth']
#
# Epoch:  32
# queen 5 most similar words: ['border', 'lendings', 'divides', 'violate', 'sixth']
# throne 5 most similar words: ['scowl', 'riddle', 'degrees', 'progress', 'hairless']
# wine 5 most similar words: ['merited', 'importuned', 'scowl', 'distraind', 'degrees']
# poison 5 most similar words: ['importuned', 'merited', 'safely', 'scowl', 'lines']
# love 5 most similar words: ['enfranchised', 'falcon', 'hairs', 'libels', 'pines']
# strong 5 most similar words: ['importuned', 'named', 'degrees', 'tick', 'hairless']
# day 5 most similar words: ['hairs', 'falcon', 'enfranchised', 'quoifs', 'tempers']
# the 5 most similar words: ['refuse', 'unvenerable', 'orange', 'coals', 'duellist']
#
# Epoch:  33
# queen 5 most similar words: ['refuse', 'unvenerable', 'orange', 'distinguishd', 'wave']
# throne 5 most similar words: ['scowl', 'riddle', 'degrees', 'progress', 'hairless']
# wine 5 most similar words: ['merited', 'importuned', 'scowl', 'distraind', 'degrees']
# poison 5 most similar words: ['importuned', 'merited', 'safely', 'scowl', 'lines']
# love 5 most similar words: ['enfranchised', 'falcon', 'hairs', 'libels', 'pines']
# strong 5 most similar words: ['importuned', 'named', 'degrees', 'tick', 'hairless']
# day 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
# the 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
#
# Epoch:  34
# queen 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'wave']
# throne 5 most similar words: ['sap', 'squirrel', 'distaffs', 'adonis', 'equals']
# wine 5 most similar words: ['sap', 'hairless', 'foretold', 'hannibal', 'fallst']
# poison 5 most similar words: ['sap', 'replied', 'sounds', 'distaffs', 'plucking']
# love 5 most similar words: ['hastily', 'mongers', 'enfranchised', 'conquer', 'bill']
# strong 5 most similar words: ['bill', 'enfranchised', 'succeeders', 'mongers', 'conquer']
# day 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
# the 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
#
# Epoch:  35
# queen 5 most similar words: ['undiscernible', 'debatement', 'hereby', 'issued', 'withs']
# throne 5 most similar words: ['sap', 'squirrel', 'distaffs', 'adonis', 'equals']
# wine 5 most similar words: ['sap', 'hairless', 'foretold', 'hannibal', 'fallst']
# poison 5 most similar words: ['sap', 'replied', 'sounds', 'distaffs', 'plucking']
# love 5 most similar words: ['sap', 'replied', 'distaffs', 'hairless', 'equals']
# strong 5 most similar words: ['sap', 'distaffs', 'equals', 'replied', 'follower']
# day 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
# the 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
#
# Epoch:  36
# queen 5 most similar words: ['modesties', 'interrupted', 'shops', 'tigers', 'prefers']
# throne 5 most similar words: ['bill', 'prizes', 'entombed', 'forerun', 'blaze']
# wine 5 most similar words: ['bill', 'enfranchised', 'blaze', 'kinsmans', 'alehouse']
# poison 5 most similar words: ['bill', 'enfranchised', 'blaze', 'alehouse', 'kinsmans']
# love 5 most similar words: ['enfranchised', 'bill', 'alehouse', 'degrees', 'prizes']
# strong 5 most similar words: ['entering', 'bier', 'turtles', 'prudent', 'inauspicious']
# day 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'demise']
# the 5 most similar words: ['refuse', 'unvenerable', 'orange', 'wave', 'coals']
#
# Epoch:  37
# queen 5 most similar words: ['recovery', 'boding', 'instrument', 'thankings', 'abusing']
# throne 5 most similar words: ['entombed', 'sap', 'ledas', 'ethiopes', 'squarest']
# wine 5 most similar words: ['sap', 'ethiopes', 'enfranchised', 'tempers', 'prolixity']
# poison 5 most similar words: ['sap', 'exhales', 'continually', 'ginger', 'enfranchised']
# love 5 most similar words: ['sap', 'enfranchised', 'quoifs', 'exhales', 'businesses']
# strong 5 most similar words: ['sap', 'prolixity', 'enfranchised', 'entombed', 'continually']
# day 5 most similar words: ['sap', 'exhales', 'businesses', 'enfranchised', 'quoifs']
# the 5 most similar words: ['refuse', 'unvenerable', 'distinguishd', 'orange', 'wave']
#
# Epoch:  38
# queen 5 most similar words: ['recovery', 'instrument', 'exiled', 'jacob', 'fairest']
# throne 5 most similar words: ['entombed', 'sap', 'ledas', 'ethiopes', 'squarest']
# wine 5 most similar words: ['sap', 'enfranchised', 'ethiopes', 'tempers', 'prolixity']
# poison 5 most similar words: ['sap', 'exhales', 'continually', 'ginger', 'enfranchised']
# love 5 most similar words: ['sap', 'enfranchised', 'quoifs', 'exhales', 'businesses']
# strong 5 most similar words: ['sap', 'prolixity', 'enfranchised', 'entombed', 'continually']
# day 5 most similar words: ['sap', 'exhales', 'businesses', 'enfranchised', 'quoifs']
# the 5 most similar words: ['bolt', 'dutys', 'distinguishd', 'orange', 'wave']
#
# Epoch:  39
# queen 5 most similar words: ['badges', 'pout', 'ifs', 'fasten', 'lendings']
# throne 5 most similar words: ['seasons', 'helped', 'tyrannical', 'doubleness', 'jested']
# wine 5 most similar words: ['seasons', 'helped', 'jested', 'doubleness', 'intercepted']
# poison 5 most similar words: ['safely', 'solemn', 'doubleness', 'jested', 'darling']
# love 5 most similar words: ['badges', 'pout', 'ifs', 'waken', 'fasten']
# strong 5 most similar words: ['seasons', 'undiscernible', 'endue', 'doubleness', 'jested']
# day 5 most similar words: ['vehement', 'jested', 'safely', 'grew', 'derivative']
# the 5 most similar words: ['splitting', 'flaying', 'forceful', 'di', 'shares']
#
# Epoch:  40
# queen 5 most similar words: ['replied', 'barricado', 'strucken', 'dug', 'doubleness']
# throne 5 most similar words: ['undiscernible', 'seasons', 'endeavours', 'dug', 'tyrannical']
# wine 5 most similar words: ['undiscernible', 'seasons', 'oppression', 'jested', 'trembles']
# poison 5 most similar words: ['undiscernible', 'seasons', 'trembles', 'safely', 'solemn']
# love 5 most similar words: ['replied', 'barricado', 'strucken', 'doubleness', 'dug']
# strong 5 most similar words: ['seasons', 'undiscernible', 'jested', 'endeavours', 'couple']
# day 5 most similar words: ['barricado', 'replied', 'strucken', 'dug', 'doubleness']
# the 5 most similar words: ['replied', 'barricado', 'strucken', 'dug', 'doubleness']
#
# Epoch:  41
# queen 5 most similar words: ['replied', 'barricado', 'island', 'digressing', 'avoided']
# throne 5 most similar words: ['greediness', 'trembles', 'grew', 'navel', 'mindless']
# wine 5 most similar words: ['barricado', 'replied', 'navel', 'doubleness', 'trembles']
# poison 5 most similar words: ['undiscernible', 'trembles', 'safely', 'holiness', 'solemn']
# love 5 most similar words: ['replied', 'barricado', 'doubleness', 'flamens', 'mindless']
# strong 5 most similar words: ['undiscernible', 'endue', 'holiness', 'navel', 'couple']
# day 5 most similar words: ['pout', 'annoy', 'graven', 'barricado', 'replied']
# the 5 most similar words: ['replied', 'barricado', 'avoided', 'island', 'advocate']
#
# Epoch:  42
# queen 5 most similar words: ['recovery', 'sweetness', 'annoy', 'waken', 'admonition']
# throne 5 most similar words: ['greediness', 'trembles', 'grew', 'navel', 'mindless']
# wine 5 most similar words: ['shops', 'hereby', 'named', 'proceeding', 'graves']
# poison 5 most similar words: ['undiscernible', 'trembles', 'holiness', 'solemn', 'endue']
# love 5 most similar words: ['undiscernible', 'libels', 'endue', 'holiness', 'julietta']
# strong 5 most similar words: ['undiscernible', 'endue', 'holiness', 'navel', 'libels']
# day 5 most similar words: ['recovery', 'annoy', 'sweetness', 'admonition', 'waken']
# the 5 most similar words: ['recovery', 'annoy', 'sweetness', 'waken', 'holes']
#
# Epoch:  43
# queen 5 most similar words: ['graven', 'fasten', 'bill', 'eternal', 'goods']
# throne 5 most similar words: ['softest', 'behests', 'knight', 'falcon', 'wiped']
# wine 5 most similar words: ['softest', 'falcon', 'otherwise', 'partialize', 'stinging']
# poison 5 most similar words: ['partialize', 'otherwise', 'falcon', 'softest', 'stinging']
# love 5 most similar words: ['softest', 'falcon', 'partialize', 'intents', 'stinging']
# strong 5 most similar words: ['softest', 'jelly', 'otherwise', 'factionary', 'partialize']
# day 5 most similar words: ['softest', 'falcon', 'partialize', 'behests', 'intents']
# the 5 most similar words: ['graven', 'fasten', 'bill', 'otherwise', 'eternal']
#
# Epoch:  44
# queen 5 most similar words: ['softest', 'falcon', 'intents', 'behests', 'stinging']
# throne 5 most similar words: ['softest', 'behests', 'falcon', 'knight', 'intents']
# wine 5 most similar words: ['softest', 'falcon', 'stinging', 'touched', 'behests']
# poison 5 most similar words: ['falcon', 'softest', 'stinging', 'atlas', 'behests']
# love 5 most similar words: ['softest', 'falcon', 'intents', 'stinging', 'behests']
# strong 5 most similar words: ['softest', 'jelly', 'stinging', 'intents', 'slipt']
# day 5 most similar words: ['softest', 'falcon', 'behests', 'intents', 'immediate']
# the 5 most similar words: ['softest', 'falcon', 'intents', 'stinging', 'slipt']
#
# Epoch:  45
# queen 5 most similar words: ['softest', 'falcon', 'jelly', 'intents', 'behests']
# throne 5 most similar words: ['softest', 'behests', 'falcon', 'knight', 'intents']
# wine 5 most similar words: ['softest', 'falcon', 'stinging', 'touched', 'behests']
# poison 5 most similar words: ['dice', 'falcon', 'softest', 'stinging', 'atlas']
# love 5 most similar words: ['softest', 'jelly', 'falcon', 'intents', 'stinging']
# strong 5 most similar words: ['arbitrement', 'softest', 'jelly', 'ebb', 'stinging']
# day 5 most similar words: ['softest', 'jelly', 'falcon', 'behests', 'intents']
# the 5 most similar words: ['softest', 'falcon', 'jelly', 'intents', 'stinging']
#
# Epoch:  46
# queen 5 most similar words: ['frights', 'distemperature', 'admonition', 'felon', 'grievances']
# throne 5 most similar words: ['softest', 'behests', 'falcon', 'knight', 'intents']
# wine 5 most similar words: ['admonition', 'tewksbury', 'intercepted', 'viewing', 'forerun']
# poison 5 most similar words: ['falcon', 'softest', 'atlas', 'behests', 'cue']
# love 5 most similar words: ['softest', 'falcon', 'intents', 'behests', 'intercepted']
# strong 5 most similar words: ['softest', 'admonition', 'foolery', 'intents', 'tewksbury']
# day 5 most similar words: ['frights', 'distemperature', 'softest', 'felon', 'oppress']
# the 5 most similar words: ['frights', 'distemperature', 'felon', 'meekness', 'oppress']
#
# Epoch:  47
# queen 5 most similar words: ['frights', 'distemperature', 'softest', 'felon', 'grievances']
# throne 5 most similar words: ['softest', 'slight', 'behests', 'interest', 'unreverent']
# wine 5 most similar words: ['softest', 'touched', 'behests', 'intercepted', 'intents']
# poison 5 most similar words: ['dice', 'intercepted', 'softest', 'atlas', 'behests']
# love 5 most similar words: ['softest', 'intents', 'behests', 'intercepted', 'cue']
# strong 5 most similar words: ['poland', 'ifs', 'softest', 'blinding', 'otherwise']
# day 5 most similar words: ['frights', 'distemperature', 'softest', 'felon', 'oppress']
# the 5 most similar words: ['frights', 'distemperature', 'felon', 'softest', 'meekness']
#
# Epoch:  48
# queen 5 most similar words: ['solace', 'passengers', 'sciatica', 'vitae', 'softest']
# throne 5 most similar words: ['softest', 'slight', 'interest', 'unreverent', 'disturb']
# wine 5 most similar words: ['softest', 'touched', 'intercepted', 'intents', 'viewing']
# poison 5 most similar words: ['dice', 'intercepted', 'softest', 'atlas', 'cue']
# love 5 most similar words: ['softest', 'intents', 'encountering', 'intercepted', 'cue']
# strong 5 most similar words: ['poland', 'ifs', 'softest', 'blinding', 'alterd']
# day 5 most similar words: ['solace', 'passengers', 'sciatica', 'softest', 'associate']
# the 5 most similar words: ['drave', 'unactive', 'wheresoeer', 'softest', 'enlargement']
#
# Epoch:  49
# queen 5 most similar words: ['solace', 'passengers', 'sciatica', 'vitae', 'softest']
# throne 5 most similar words: ['softest', 'slight', 'choked', 'interest', 'unreverent']
# wine 5 most similar words: ['softest', 'touched', 'intercepted', 'intents', 'viewing']
# poison 5 most similar words: ['dice', 'intercepted', 'softest', 'atlas', 'cue']
# love 5 most similar words: ['solace', 'passengers', 'sciatica', 'softest', 'jelly']
# strong 5 most similar words: ['poland', 'ifs', 'softest', 'blinding', 'alterd']
# day 5 most similar words: ['solace', 'passengers', 'sciatica', 'softest', 'associate']
# the 5 most similar words: ['solace', 'passengers', 'sciatica', 'vitae', 'graceless']

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 41062), started 0:45:47 ago. (Use '!kill 41062' to kill it.)
#       <iframe id="tensorboard-frame-b00710d79c93f5da" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b00710d79c93f5da");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
